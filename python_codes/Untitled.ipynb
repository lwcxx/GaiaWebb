# %%
import os
import numpy as np
import shutil

# %%
path = '/home/jupyter-lwchen/data_km/bp3m/GaiaWebb-master/python_codes/'
poss_dirs = np.array(os.listdir(path))

good_dirs = np.zeros(len(poss_dirs)).astype(bool)
for j,name in enumerate(poss_dirs):
    good_dirs[j] = os.path.isdir(f'{path}{name}')
good_dir_names = poss_dirs[good_dirs]

# %%
pwd()
# Out:
# '/bootes_raid6/users/kmckinnon/bp3m/GaiaWebb-master/python_codes'

# %%
for j,name in enumerate(good_dir_names):
    print(name,os.path.isdir(f'{path}{name}'))
    if os.path.isdir(f'{path}{name}'):
        try:
            shutil.rmtree(f'{path}{name}')
        except:
            continue
# Out:
# MACSJ1423.8+2404 False
# LMC_new False
# LMC_z False
# NGC-1514 False
# ABELL2744 False
# GAL-CENTER-Tile-3 False
# tmp_NGC-6723 True
# __pycache__ True
# M-83 True
# SMP_LMC_58 True
# Virgo_Cluster True
# IC-860 True
# NGC-300 True
# MACSJ0416.1-2403 True
# Draco_dSph True
# tmp_NGC True
# tmp_CYGNUS-A-MRS True
# tmp_Draco_dSph_jwst1pass_copy True
# J0226P0302 True
# NGC-4418 True
# M22 True
# NGC-6240 True
# NGC-2981 True
# ESO420-G13 True
# tmp_NGC-6528 True
# MACSJ1149+2223 True
# tmp_NGC-288 True
# tmp_NGC4299 True
# NGC-288 True
# NGC-6723 True
# NIRISS-NEW-FOCUS-FIELD True
# NGC4299 True
# NGC-4051 True
# ABELL-2597 True
# NGC True
# Draco_dSph_jwst1pass_copy True
# NGC-3227 True
# tmp_NGC-6553 True
# tmp_LMC_test True
# NGC-6553 True
# LMC True
# LMC_miri True
# LDS749B True
# Draco_dSph_jwst1pass True
# ABELL370 True
# CYGNUS-A-MRS True
# tmp_Virgo_Cluster True
# tmp_NGC-6822 True
# tmp_Omega_Cen True
# IC348-MOSAIC True
# WDFS0122-30 True
# W2246 True
# CLG-0451-03 True
# ...
